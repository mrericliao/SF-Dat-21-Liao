# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import socket, struct
# Out:
# /Users/EricBGLiao/anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
train_df = pd.read_csv('train_spain.csv')

# %%
test_df = pd.read_csv('test_spain.csv')
# Out:
# /Users/EricBGLiao/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (19,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train_df.columns
# Out:
# Index([u'start_ip_int', u'end_ip_int', u'start_ip_oct', u'end_ip_oct',
#        u'continent', u'country', u'country_code', u'country_cf', u'region',
#        u'state', u'state_code', u'state_cf', u'city', u'city_cf',
#        u'postal_code', u'area_code', u'time_zone', u'latitude', u'longitude',
#        u'dma', u'msa', u'connection_type', u'line_speed', u'ip_routing_type',
#        u'asn', u'sld', u'tld', u'organization', u'carrier'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index([u'cb_count', u'c_block', u'skyhook_ip', u'skyhook_lat', u'skyhook_lon',
#        u'skyhook_cf', u'country', u'state', u'city', u'postal', u'lat', u'lon',
#        u'dist_from_sh', u'gpp_start_ip', u'gpp_end_ip', u'gpp_country',
#        u'gpp_state', u'gpp_city', u'gpp_postalcode', u'gpp_citylatitude',
#        u'gpp_citylongitude', u'connectiontype', u'iproutingtype', u'asn',
#        u'registeringorganization', u'carrier', u'home', u'hostingfacility',
#        u'source', u'dist_gpp'],
#       dtype='object')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125851 entries, 0 to 125850
# Data columns (total 29 columns):
# start_ip_int       125851 non-null int64
# end_ip_int         125851 non-null int64
# start_ip_oct       125851 non-null object
# end_ip_oct         125851 non-null object
# continent          125851 non-null object
# country            125851 non-null object
# country_code       125851 non-null object
# country_cf         125851 non-null int64
# region             92522 non-null object
# state              93657 non-null object
# state_code         98 non-null object
# state_cf           93657 non-null float64
# city               93657 non-null object
# city_cf            93657 non-null float64
# postal_code        91790 non-null object
# area_code          98 non-null float64
# time_zone          93657 non-null float64
# latitude           125851 non-null float64
# longitude          125851 non-null float64
# dma                95 non-null float64
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125851 entries, 128 to 144
# Data columns (total 30 columns):
# cb_count                   125851 non-null object
# c_block                    125851 non-null object
# skyhook_ip                 125851 non-null float64
# skyhook_lat                125851 non-null float64
# skyhook_lon                125851 non-null int64
# skyhook_cf                 125851 non-null object
# country                    125851 non-null object
# state                      125851 non-null object
# city                       125851 non-null object
# postal                     125851 non-null object
# lat                        125851 non-null float64
# lon                        125851 non-null float64
# dist_from_sh               125851 non-null float64
# gpp_start_ip               125851 non-null int64
# gpp_end_ip                 125851 non-null int64
# gpp_country                125851 non-null object
# ...

# %%
train_df
# Out:
#         start_ip_int  end_ip_int    start_ip_oct       end_ip_oct continent  \
# 0           34612736    34612991       2.16.38.0      2.16.38.255    europe
# 1           34612992    34613247       2.16.39.0      2.16.39.255    europe
# 2           34613760    34614271       2.16.42.0      2.16.43.255    europe
# 3           34622976    34623487       2.16.78.0      2.16.79.255    europe
# 4           34641408    34641663      2.16.150.0     2.16.150.255    europe
# 5           34685696    34685951       2.17.67.0      2.17.67.255    europe
# 6           34912512    34912767      2.20.185.0     2.20.185.255    europe
# 7           34913280    34914303      2.20.188.0     2.20.191.255    europe
# 8           34914304    34918399      2.20.192.0     2.20.207.255    europe
# 9           34926592    34927103      2.20.240.0     2.20.241.255    europe
# 10          35055104    35055359      2.22.230.0     2.22.230.255    europe
# ...

# %%
test_df
# Out:
#      cb_count       c_block  skyhook_ip  skyhook_lat  skyhook_lon  \
# 128   1.38.34    1.38.34.87   43.210747    -2.003609           -1
# 26   1.38.209   1.38.209.75   42.696923    -1.356654           -1
# 6    1.38.242   1.38.242.76   41.794022    -3.624343           -1
# 132  1.39.130  1.39.130.172   41.797893     2.045539           -1
# 147  1.41.128    1.41.128.9   42.571356    -1.309684           -1
# 7    1.51.253  1.51.253.152   42.340569     2.556100           -1
# 168  1.164.70   1.164.70.99   37.130997    -0.818565           -1
# 51     2.0.42    2.0.42.121   41.425708     2.228699           -1
# 58    2.0.171   2.0.171.237   41.425681     2.228749           -1
# 67     2.3.23    2.3.23.165   42.134486    -0.850887           -1
# 72    2.6.137   2.6.137.184   41.458163     0.747994           -1
# 193  2.34.186  2.34.186.124   38.538818     2.151733           -1
# 46   2.38.203   2.38.203.54   40.024475     3.562783           -1
# ...

# %%
test_df.rename(columns = {'c_block':'end_ip_oct'}, inplace = True)

# %%
pd.merge(test_df, train_df, on="end_ip_oct")
# Out:
#      cb_count     end_ip_oct  skyhook_ip  skyhook_lat  skyhook_lon  \
# 0     2.136.1    2.136.1.255   40.209595    -5.081421          100
# 1    2.136.14   2.136.14.255   41.385784     2.133420          100
# 2    2.136.41   2.136.41.255   41.318571     2.021855       420890
# 3    2.136.42   2.136.42.255   41.389146     2.008426       420890
# 4    2.136.56   2.136.56.255   40.390434    -3.733762       420890
# 5    2.136.66   2.136.66.255   40.383886    -3.744567       420890
# 6    2.136.67   2.136.67.255   28.920273   -13.657272       420890
# 7    2.136.69   2.136.69.255   40.334009    -3.871340       420890
# 8    2.136.80   2.136.80.255   40.337416    -3.394596       420890
# 9    2.136.81   2.136.81.255   38.909110    -6.951557       420890
# 10   2.136.84   2.136.84.255   38.926094    -6.345458       420890
# 11   2.136.94   2.136.94.255   42.554341    -8.990769       420890
# 12  2.136.106  2.136.106.255   40.473916    -3.875551       420890
# ...

# %%
merge_df = pd.merge(test_df, train_df, on="end_ip_oct")

# %%
merge_df
# Out:
#      cb_count     end_ip_oct  skyhook_ip  skyhook_lat  skyhook_lon  \
# 0     2.136.1    2.136.1.255   40.209595    -5.081421          100
# 1    2.136.14   2.136.14.255   41.385784     2.133420          100
# 2    2.136.41   2.136.41.255   41.318571     2.021855       420890
# 3    2.136.42   2.136.42.255   41.389146     2.008426       420890
# 4    2.136.56   2.136.56.255   40.390434    -3.733762       420890
# 5    2.136.66   2.136.66.255   40.383886    -3.744567       420890
# 6    2.136.67   2.136.67.255   28.920273   -13.657272       420890
# 7    2.136.69   2.136.69.255   40.334009    -3.871340       420890
# 8    2.136.80   2.136.80.255   40.337416    -3.394596       420890
# 9    2.136.81   2.136.81.255   38.909110    -6.951557       420890
# 10   2.136.84   2.136.84.255   38.926094    -6.345458       420890
# 11   2.136.94   2.136.94.255   42.554341    -8.990769       420890
# 12  2.136.106  2.136.106.255   40.473916    -3.875551       420890
# ...
