# %% [markdown]
# # SF-DAT-21 | Unit Project 2
#
# In this project, you will implement the exploratory analysis plan developed in Unit Project 1.  This will lay the groundwork for our our first modeling exercise in Unit Project 3.

# %% [markdown]
# ### Step 1: Load the python libraries you will need for this project

# %%
# imports
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
# %matplotlib inline

# %% [markdown]
# ### Step 2: Read in your data set

# %%
# read in data from source
df_raw = pd.read_csv("../../dataset/admissions.csv")
print df_raw.head()
# Out:
#    admit  gre   gpa  prestige
# 0      0  380  3.61         3
# 1      1  660  3.67         3
# 2      1  800  4.00         1
# 3      1  640  3.19         4
# 4      0  520  2.93         4

# %% [markdown]
# ## Questions
# #### Question 1. How many observations are in our dataset?

# %%
df_raw.count()
# Out:
# admit       400
# gre         398
# gpa         398
# prestige    399
# dtype: int64

# %% [markdown]
# Answer: 4

# %% [markdown]
# #### Question 2. Create a summary table.

# %%
df_raw
# Out:
#      admit  gre   gpa  prestige
# 0        0  380  3.61         3
# 1        1  660  3.67         3
# 2        1  800  4.00         1
# 3        1  640  3.19         4
# 4        0  520  2.93         4
# 5        1  760  3.00         2
# 6        1  560  2.98         1
# 7        0  400  3.08         2
# 8        1  540  3.39         3
# 9        0  700  3.92         2
# 10       0  800  4.00         4
# 11       0  440  3.22         1
# 12       1  760  4.00         1
# 13       0  700  3.08         2
# 14       1  700  4.00         1
# 15       0  480  3.44         3
# 16       0  780  3.87         4
# 17       0  360  2.56         3
# 18       0  800  3.75         2
# 19       1  540  3.81         1
# 20       0  500  3.17         3
# 21       1  660  3.63         2
# 22       0  600  2.82         4
# 23       0  680  3.19         4
# 24       1  760  3.35         2
# 25       1  800  3.66         1
# 26       1  620  3.61         1
# 27       1  520  3.74         4
# ...

# %% [markdown]
# #### Question 3. Why would GRE have a larger STD than GPA?

# %% [markdown]
# Answer: GRE Scores have a longer range than GPA (0-800 vs 0-4)

# %% [markdown]
# #### Question 4. Drop data points with missing data.

# %%
df_raw.dropna ()
# Out:
#      admit  gre   gpa  prestige
# 0        0  380  3.61         3
# 1        1  660  3.67         3
# 2        1  800  4.00         1
# 3        1  640  3.19         4
# 4        0  520  2.93         4
# 5        1  760  3.00         2
# 6        1  560  2.98         1
# 7        0  400  3.08         2
# 8        1  540  3.39         3
# 9        0  700  3.92         2
# 10       0  800  4.00         4
# 11       0  440  3.22         1
# 12       1  760  4.00         1
# 13       0  700  3.08         2
# 14       1  700  4.00         1
# 15       0  480  3.44         3
# 16       0  780  3.87         4
# 17       0  360  2.56         3
# 18       0  800  3.75         2
# 19       1  540  3.81         1
# 20       0  500  3.17         3
# 21       1  660  3.63         2
# 22       0  600  2.82         4
# 23       0  680  3.19         4
# 24       1  760  3.35         2
# 25       1  800  3.66         1
# 26       1  620  3.61         1
# 27       1  520  3.74         4
# ...

# %% [markdown]
# #### Question 5. Confirm that you dropped the correct data.  How can you tell?

# %% [markdown]
# Answer: 3 rows were dropped from the table.

# %%
df_raw.isnull().sum()
# Out:
# admit       0
# gre         2
# gpa         2
# prestige    1
# dtype: int64

# %% [markdown]
# #### Question 6. Create box plots for GRE and GPA.

# %%
df_raw['gre'].plot(kind = 'box')

# %%
df_raw['gpa'].plot(kind = 'box')

# %% [markdown]
# #### Question 7. What do this plots show?

# %% [markdown]
# Answer: Median, range, and interquartile range for gre & gpa.

# %% [markdown]
# #### Question 8. Describe each distribution.

# %%
df_raw.describe ()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000  520.000000    3.13000    2.000000
# 50%      0.000000  580.000000    3.39500    2.000000
# 75%      1.000000  660.000000    3.67000    3.000000
# max      1.000000  800.000000    4.00000    4.000000

# %% [markdown]
# #### Question 9. If our model had an assumption of a normal distribution would we meet that requirement?

# %% [markdown]
# Answer: No, because you can't have a GPA or GRE < 0.

# %% [markdown]
# #### Question 10. Does this distribution need correction?  If so, why?  How?

# %% [markdown]
# Answer: Yes, it is not a natural bell curve, so our curve will be skewed to the right.

# %% [markdown]
# #### Question 11. Which of our variables are potentially colinear?

# %%
df_raw.corr ()
# Out:
#              admit       gre       gpa  prestige
# admit     1.000000  0.182919  0.175952 -0.241355
# gre       0.182919  1.000000  0.382408 -0.124533
# gpa       0.175952  0.382408  1.000000 -0.059031
# prestige -0.241355 -0.124533 -0.059031  1.000000

# %% [markdown]
# #### Question 12. What did you find?

# %% [markdown]
# Answer: GRE and GPA are positively colinear to admit.

# %% [markdown]
# #### Question 13. Write an analysis plan for exploring the association between grad school admissions rates and prestige of undergraduate schools.

# %% [markdown]
# Answer: Check data on: prestige, admit, gre, and gpa for the students who applied to UC Davis law school in the 2015-2016 academic year.

# %% [markdown]
# #### Question 14. What is your hypothesis?

# %% [markdown]
# Answer: My hypothesis is that prestige alone is not a good predictive indicator on whether a student will be admitted into UC Davis law school.  Having a high GRE & GPA score are more important than coming from a prestigious school, in regards to being admitted.

# %% [markdown]
# ## Bonus/Advanced

# %% [markdown]
# #### 1. Bonus: Explore alternatives to dropping obervations with missing data.

# %% [markdown]
# #### 2. Bonus: Log transform the skewed data.

# %% [markdown]
# #### 3. Advanced: Impute missing data.
